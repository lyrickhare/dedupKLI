# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\lyric\.keras-ocr\craft_mlt_25k.h5
# Downloading C:\Users\lyric\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\lyric\.keras-ocr\crnn_kurapan.h5
# Downloading C:\Users\lyric\.keras-ocr\crnn_kurapan.h5

# %%
images = [keras_ocr.tools.read('image.jpg')]

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 11s 11s/step
# 2/2 [==============================] - 4s 703ms/step

# %%
fig, axs = plt.subplots(nrows=len(images)+1, figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)

# %%
predicted_image = prediction_groups[0]

# %%
for text, box in predicted_image:
    print(text)
# Out:
# fanitst
# prcn
# trd
# btacx
# india
# of
# govt
# income
# tax
# department
# pls
# cheat
# tircat
# bitet
# card
# number
# account
# permanent
# kbqpki459a
# name
# i
# khare
# lyric
# fudl
# fathers
# name
# ct
# l
# khare
# umashankar
# 3102120
# khare
# ared
# ct
# srh
# lyric
# birth
# date
# of
# edigr
# signature
# 1710312002
# l
